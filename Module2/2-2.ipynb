# %%
# cell
# Ctrl + Enter 執行 Cell
# A 往上新增 Cell
# B 往下新增 Cell
# X 刪除 Cell

# %%
x = 10
print(x)
print(x)
print(x)
# Out:
# 10

# %%
# VS code IDE 快捷鍵
# Alt + 上下 移動程式碼
# Ctrl + D 一次修改多個變數
# Alt + shift + 上下  複製某一行程式碼
# 快速打開/關閉終端機 Ctrl + `

# %%
# 常數(通常視為不會改變的變數)=> 會用全大寫去命名
