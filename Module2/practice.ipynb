# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
total = 2000

if total >= 2000:
   total -=200 #total = total -200
   
print(total)
# Out:
# 1800

# %%
total = 6500

if total >= 2000:
   #需要折幾個200
   total -= 200 * (total//2000) #total = total -200
print(total)
# Out:
# 5900
